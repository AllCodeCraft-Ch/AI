# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.svm import SVC
from sklearn.datasets import make_blobs

# %%
import numpy as np

x = np.array([[1, 2],
              [2, 3],
              [3, 4]])

y = np.array([0, 1, 1])

w = np.random.rand(2)

b = 0.0

eta = 0.01

def step_function(z):
    return 1 if z > 0 else 0

def train_slp(x, y, w, b, eta, epochs):
    n_samples, n_feature = x.shape

    for epoch in range(epochs):
        total_error = 0
        for i in range(n_samples):
            z = np.dot(x[i], w) + b
            y_pred = step_function(z)

            error = y[i] - y_pred

            w += eta * error * x[i]
            b += eta * error

            total_error += np.abs(error) #error ** 2

        print(f'Epoch {epoch+1}, Total Error: {total_error}, Weights: {w}, Bias: {b}')

        if total_error == 0:
            break

    return w, b

epochs = 100
w_final, b_final = train_slp(x, y, w, b, eta, epochs)

print(f'Final Weights: {w_final}, Final Bias: {b_final}')
# Out:
# Epoch 1, Total Error: 1, Weights: [0.13685248 0.5438803 ], Bias: -0.01
# Epoch 2, Total Error: 1, Weights: [0.12685248 0.5238803 ], Bias: -0.02
# Epoch 3, Total Error: 1, Weights: [0.11685248 0.5038803 ], Bias: -0.03
# Epoch 4, Total Error: 1, Weights: [0.10685248 0.4838803 ], Bias: -0.04
# Epoch 5, Total Error: 1, Weights: [0.09685248 0.4638803 ], Bias: -0.05
# Epoch 6, Total Error: 1, Weights: [0.08685248 0.4438803 ], Bias: -0.060000000000000005
# Epoch 7, Total Error: 1, Weights: [0.07685248 0.4238803 ], Bias: -0.07
# Epoch 8, Total Error: 1, Weights: [0.06685248 0.4038803 ], Bias: -0.08
# Epoch 9, Total Error: 1, Weights: [0.05685248 0.3838803 ], Bias: -0.09
# Epoch 10, Total Error: 1, Weights: [0.04685248 0.3638803 ], Bias: -0.09999999999999999
# Epoch 11, Total Error: 1, Weights: [0.03685248 0.3438803 ], Bias: -0.10999999999999999
# Epoch 12, Total Error: 1, Weights: [0.02685248 0.3238803 ], Bias: -0.11999999999999998
# Epoch 13, Total Error: 1, Weights: [0.01685248 0.3038803 ], Bias: -0.12999999999999998
# Epoch 14, Total Error: 1, Weights: [0.00685248 0.2838803 ], Bias: -0.13999999999999999
# Epoch 15, Total Error: 1, Weights: [-0.00314752  0.2638803 ], Bias: -0.15
# Epoch 16, Total Error: 1, Weights: [-0.01314752  0.2438803 ], Bias: -0.16
# Epoch 17, Total Error: 1, Weights: [-0.02314752  0.2238803 ], Bias: -0.17
# Epoch 18, Total Error: 1, Weights: [-0.03314752  0.2038803 ], Bias: -0.18000000000000002
# Epoch 19, Total Error: 1, Weights: [-0.04314752  0.1838803 ], Bias: -0.19000000000000003
# Epoch 20, Total Error: 1, Weights: [-0.05314752  0.1638803 ], Bias: -0.20000000000000004
# Epoch 21, Total Error: 1, Weights: [-0.06314752  0.1438803 ], Bias: -0.21000000000000005
# Epoch 22, Total Error: 1, Weights: [-0.07314752  0.1238803 ], Bias: -0.22000000000000006
# Epoch 23, Total Error: 0, Weights: [-0.07314752  0.1238803 ], Bias: -0.22000000000000006
# Final Weights: [-0.07314752  0.1238803 ], Final Bias: -0.22000000000000006

# %%
# Plotting the sample
plt.scatter(x[y == 0][:, 0], x[y == 0][:, 1], color='red', label='Class 0')
plt.scatter(x[y == 1][:, 0], x[y == 1][:, 1], color='blue', label='Class 1')

# Define the decision boundary (w1 * x1 + w2 * x2 + b = 0)
# 0 = w_final[0] * x1 + w_final[1] * x2 + b_final
# x2 = -(w_final[0] * x1 + b_final)/w_final[1]
x1_vals = np.linspace(min(x[:, 0]) - 1, max(x[:, 0]) + 1, 100)
x2_vals = -(w_final[0] * x1_vals + b_final) / w_final[1]

# Plotting the decision bounsary
plt.plot(x1_vals, x2_vals, color='green', label='Decision Boundary')

# set plot lables and title
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Boundary for Single Layer Perceptron')
plt.legend()
# plt.grid(True)
plt.show()

# %%
import numpy as np

x = []
x.append(np.random.randn(50, 2) + 0.5)
x.append(np.random.randn(50, 2) - 0.5)
x = np.concatenate(x, axis = 0)
y = np.concatenate([np.zeros(int(x.shape[0]/2)), np.ones(int(x.shape[0]/2))], axis = 0)

indx = np.arange(x.shape[0])
np.random.shuffle(indx)

x = x[indx,:]
y = y[indx]
plt.scatter(x[y==0,0], x[y==0,1], color='red', label='Class 0')
plt.scatter(x[y==1,0], x[y==1,1], color='blue', label='Class 1')

x1_vals = np.linspace(min(x[:, 0]) - 1, max(x[:, 0]) + 1, 100)
x2_vals = -(w_final[0] * x1_vals + b_final) / w_final[1]

# Plotting the decision bounsary
plt.plot(x1_vals, x2_vals, color='green', label='Decision Boundary')

plt.xlabel('Feature 1')
plt.xlabel('Feature 2')
plt.legend()

plt.show()

# %%
X, y = make_blobs(n_samples=400, centers=4, random_state=42)

plt.figure(figsize=(8, 6))
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], color='red', label='Class 0')
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], color='blue', label='Class 1')
plt.scatter(X[y == 2][:, 0], X[y == 2][:, 1], color='black', label='Class 2')
plt.scatter(X[y == 3][:, 0], X[y == 3][:, 1], color='yellow', label='Class 3')
plt.legend()
plt.show()

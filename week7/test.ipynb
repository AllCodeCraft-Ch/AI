# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
import numpy as np

x = []
x.append(np.random.randn(50, 2) + 0.5)
x.append(np.random.randn(50, 2) - 0.5)
x = np.concatenate(x, axis = 0)
y = np.concatenate([np.zeros(int(x.shape[0]/2)), np.ones(int(x.shape[0]/2))], axis = 0)

indx = np.arange(x.shape[0])
np.random.shuffle(indx)

x = x[indx,:]
y = y[indx]

plt.scatter(x[y==0,0], x[y==0,1], color='red', label='Class 0')
plt.scatter(x[y==1,0], x[y==1,1], color='blue', label='Class 1')

plt.xlabel('Feature 1')
plt.xlabel('Feature 2')
plt.legend()

plt.show()

# %%
x = []
x.append(np.random.rand(50, 2) + 0.5)
x.append(np.random.rand(50, 2) - 0.5)
x = np.concatenate(x, axis = 0)
y = np.concatenate([np.zeros(int(x.shape[0]/2)), np.ones(int(x.shape[0]/2))], axis = 0)

indx = np.arange(x.shape[0])
np.random.shuffle(indx)
x = x[indx,:]
y = y[indx]

print(x[y==0,0])
# Out:
# [1.44179008 1.34728947 0.80885398 1.09298338 0.56705146 0.95755954
#  0.75689079 0.98351155 0.96706543 0.9253392  1.29563036 1.29954667
#  1.49079204 0.95575644 0.53042585 0.88237046 1.24164732 0.82869882
#  1.18474835 1.48073436 1.2063781  0.99533817 1.03601586 1.05573312
#  0.96431259 0.72911659 1.49368286 0.85207682 1.37150397 0.66660954
#  1.15133295 1.29426422 0.82665805 1.45719176 0.78136383 0.91608513
#  1.15138324 0.57443744 1.27263849 0.77117506 1.38523327 0.61668129
#  0.58800296 1.47926663 1.48034608 0.79391216 1.49632063 1.22048431
#  1.27191689 1.13106479]

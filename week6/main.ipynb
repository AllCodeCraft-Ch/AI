# %%
# !pip install scikit-learn
# !pip install matplotlib
# !pip install pandas

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(0,8,0.1)
y = [16 - (4-xi)**2 for xi in x]

plt.plot(x, y)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

f, ax = plt.subplots(1)
# x = range(0,9)
x = np.arange(-2,10,0.1)
y = [16 - (4-xi)**2 for xi in x]

plt.plot(x, y)
ax.set_ylim(ymin=0)
ax.set_xlim(xmin=0)
plt.show()

# %%
import pandas
iris = pandas.read_csv('iris/iris.data', header=None)
iris

# %%
import pandas
columns = ['sepal length','sepal width', 'petal length', 'petal width', 'class']
iris = pandas.read_csv('iris/iris.data', header=None, names=columns)
X = iris[columns[:-1]]
Y = iris['class']

# %%
# plot sepal length between 3 classes
plt.figure(figsize=(10, 6))
# Plotting sepal length for each species
iris_classes = iris['class'].unique()
feature_name = 'petal width' # "petal length"  #'sepal width' # 'sepal length'
colors=[[1,0,0],[0,1,0],[0,0,1]]
for i, species in enumerate(iris_classes):
    cdata = X[Y['class'] == species]
    plt.plot(cdata.index, cdata[feature_name], marker='o', linestyle='', color=colors[i], label=species)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 13
#       9 colors = [[1, 0, 0], [0, 1, 0], [0, 0, 1]]  # RGB colors for different species
#      11 for i, species in enumerate(iris_classes):
#      12     # Ensure 'class' is the correct column name in Y that corresponds to species
# ---> 13     cdata = X[Y['class'] == species]
#      14     plt.plot(cdata.index, cdata[feature_name], marker='o', linestyle='', color=colors[i], label=species)
#      16 plt.title('Sepal Length Across Iris Species')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'class'

# %%
# plot sepal length between 3 classes
# plt.figure(figsize=(10, 6))

# Plotting sepal length for each species
iris_classes = iris['class'].unique()
# fn1 = 'petal width'  
# fn2 = "petal length"
fn1 = 'sepal width'  
fn2 = "sepal length"
iris['class_id'], labels = pandas.factorize(iris['class'])

plt.scatter(iris[fn1], iris[fn2], c=iris['class_id'], cmap=plt.cm.Paired, edgecolors='k' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # plot sepal length between 3 classes
#       2 # plt.figure(figsize=(10, 6))
#       3
#       4 # Plotting sepal length for each species
# ----> 5 iris_classes = iris['class'].unique()
#       6 # fn1 = 'petal width'
#       7 # fn2 = "petal length"
#       8 fn1 = 'sepal width'
#
# NameError: name 'iris' is not defined

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# Generate moons dataset
X, y = make_moons(n_samples=100, noise=0.15, random_state=42)

# Plot the dataset
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
plt.title('Moons Dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as matcolor
from sklearn.datasets import load_wine

# Load the Wine dataset
wine = load_wine()
wine_data = wine.data
wine_target = wine.target
wine_feature_names = wine.feature_names
colors = ['']
# Choose two features for the scatter plot (e.g., the first two features)
fi1 = 0
fi2 = 1

# Plot the Wine dataset
plt.figure(figsize=(10, 6))
plt.scatter(wine_data[:, fi1], wine_data[:, fi2], c=wine_target, 
            cmap=plt.cm.Paired, edgecolor='k')
plt.xlabel(wine_feature_names[fi1])
plt.ylabel(wine_feature_names[fi2])
plt.title('Wine Dataset - Scatter Plot of Two Features')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some sample data for illustration
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(-0.1 * x) * np.sin(x)
y5 = x
y6 = x**2
y7 = np.sqrt(x)
y8 = np.log(x + 1)

# Create a 4x2 subplot layout
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 10))

# Plot data on each subplot
axes[0, 0].plot(x, y1)
axes[0, 0].set_title('Feature 1')

axes[0, 1].plot(x, y2)
axes[0, 1].set_title('Feature 2')

axes[1, 0].plot(x, y3)
axes[1, 0].set_title('Feature 3')

axes[1, 1].plot(x, y4)
axes[1, 1].set_title('Feature 4')

axes[2, 0].plot(x, y5)
axes[2, 0].set_title('Feature 5')

axes[2, 1].plot(x, y6)
axes[2, 1].set_title('Feature 6')

axes[3, 0].plot(x, y7)
axes[3, 0].set_title('Feature 7')

axes[3, 1].plot(x, y8)
axes[3, 1].set_title('Feature 8')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
